# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SIMPLE-LINEAR-REGRESSION" data-toc-modified-id="SIMPLE-LINEAR-REGRESSION-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SIMPLE LINEAR REGRESSION</a></span></li><li><span><a href="#RESIDUAL-PLOT" data-toc-modified-id="RESIDUAL-PLOT-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>RESIDUAL PLOT</a></span></li><li><span><a href="#HIGHER-ORDER-REGRESSION-=-POLYNOMIAL-REGRESSION" data-toc-modified-id="HIGHER-ORDER-REGRESSION-=-POLYNOMIAL-REGRESSION-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>HIGHER-ORDER REGRESSION = POLYNOMIAL REGRESSION</a></span></li><li><span><a href="#GROUPING-FACTOR-IN-SAME-PLOT" data-toc-modified-id="GROUPING-FACTOR-IN-SAME-PLOT-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>GROUPING FACTOR IN SAME PLOT</a></span></li><li><span><a href="#GROUPING-FACTOR-IN-SUBPLOT" data-toc-modified-id="GROUPING-FACTOR-IN-SUBPLOT-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>GROUPING FACTOR IN SUBPLOT</a></span></li></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
auto = pd.read_csv('auto-mpg.csv')

# %% [markdown]
# ## SIMPLE LINEAR REGRESSION

# %%
# Import plotting modules
import seaborn as sns

# Plot a linear regression between 'weight' and 'hp'
sns.lmplot(x='weight', y='hp', data=auto)

# Display the plot
plt.show()

# %% [markdown]
# ## RESIDUAL PLOT

# %%
# Generate a green residual plot of the regression between 'hp' and 'mpg'
sns.residplot(x='hp', y='mpg', data=auto, color='green')

# Display the plot
plt.show()

# %% [markdown]
# ## HIGHER-ORDER REGRESSION = POLYNOMIAL REGRESSION

# %%
# Generate a scatter plot of 'weight' and 'mpg' using red circles
plt.scatter(auto['weight'], auto["mpg"], label='data', color='red', marker='o')

# Plot in blue a linear regression of order 1 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, color="blue", scatter=None, label='order 1')

# Plot in green a linear regression of order 2 between 'weight' and 'mpg' => polynomial regression
sns.regplot(x="weight", y = "mpg", data=auto, color="green", scatter=None, label="order 2", order = 2)

# Add a legend and display the plot
plt.legend(loc = "upper right")
plt.show()

# %% [markdown]
# ## GROUPING FACTOR IN SAME PLOT

# %%
# Plot a linear regression between 'weight' and 'hp', with a hue of 'origin' and palette of 'Set1'
sns.lmplot(x="weight", y="hp", hue="origin", data=auto, palette = "Set1")

# Display the plot
plt.show()

# %% [markdown]
# ## GROUPING FACTOR IN SUBPLOT

# %%
# Plot linear regressions between 'weight' and 'hp' grouped row-wise by 'origin'
sns.lmplot(x = "weight", y = "hp", data = auto, row="origin")

# Display the plot
plt.show()
